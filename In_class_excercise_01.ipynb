# %% [markdown]
# <a href="https://colab.research.google.com/github/KSanders-data/KaitlynSanders_DTSC3020_Summer2026/blob/main/In_class_excercise_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome")
# Out:
# welcome
