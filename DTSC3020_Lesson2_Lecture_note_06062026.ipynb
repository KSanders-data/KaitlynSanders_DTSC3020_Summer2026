# %% [markdown]
# <a href="https://colab.research.google.com/github/KSanders-data/KaitlynSanders_DTSC3020_Summer2026/blob/main/DTSC3020_Lesson2_Lecture_note_06062026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <style>
# .jp-RenderedHTMLCommon h1 { color: #0b6b3a; border-bottom: 2px solid #dcefe5; padding-bottom: 6px; }
# .jp-RenderedHTMLCommon h2 { color: #0e5f43; margin-top: 28px; }
# .jp-RenderedHTMLCommon h3 { color: #205b85; }
# .callout { border-left: 7px solid #0b6b3a; background: #f3fbf5; padding: 14px 18px; margin: 16px 0; border-radius: 8px; }
# .warning { border-left: 7px solid #b45309; background: #fff8e6; padding: 14px 18px; margin: 16px 0; border-radius: 8px; }
# .activity { border-left: 7px solid #2563eb; background: #f2f6ff; padding: 14px 18px; margin: 16px 0; border-radius: 8px; }
# .checkpoint { border-left: 7px solid #7c3aed; background: #f8f5ff; padding: 14px 18px; margin: 16px 0; border-radius: 8px; }
# .quiz { border: 1px solid #d8e2ea; background: #fbfdff; padding: 14px 18px; margin: 16px 0; border-radius: 10px; }
# .figure { margin: 18px 0 24px 0; padding: 8px; background: #ffffff; border: 1px solid #d8e2ea; border-radius: 14px; }
# .figcap { font-size: 0.9em; color: #52616b; margin-top: 6px; }
# </style>
#
# # DTSC 3020: Introduction to Computation with Python
# ## Week 2 Lecture: Variables, Data Types, Strings, Operators, and Random Numbers
#
# **Instructor:** Dr. Haihua Chen
# **Department of Data Science, University of North Texas**
#
# <div class="callout">
# <b>Big idea:</b> Variables, data types, strings, operators, and random numbers are the building blocks of almost every Python program. In the Generative AI era, these basics help students read, verify, and improve AI-generated code.
# </div>

# %% [markdown]
# ## Learning Objectives
#
# By the end of Week 2, students should be able to:
#
# 1. Define and use Python variables, identifiers, and basic data types.
# 2. Work with numeric data types and perform basic calculations.
# 3. Create and manipulate strings using common string operations.
# 4. Apply arithmetic, relational, logical, assignment, membership, identity, and basic bitwise operators.
# 5. Understand local, global, built-in, and enclosed variable scope at a beginner level.
# 6. Generate and use random numbers with Python's `random` module.
# 7. Write simple programs combining variables, data types, strings, operators, and random numbers.

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Week 2 map" width="950"/></div>

# %% [markdown]
# # Part 1. Why Week 2 Matters
#
# Last week, we learned how to run simple Python programs. This week, we learn how programs **remember information**, **understand data types**, **process text**, and **make decisions through operators**.
#
# These concepts appear in almost every real-world Python task, including:
#
# - Calculating grades
# - Cleaning survey data
# - Checking AI-generated text
# - Creating random practice problems
# - Simulating uncertain events
# - Validating user input

# %% [markdown]
# # Part 2. Variables and Data Types
#
# **Assigned reading:** [Python Variables and Data Types — DataFlair](https://data-flair.training/blogs/python-variables-and-data-types/)
#
# A variable is a name that refers to a value. Python creates a variable when a value is assigned to it.
#
# DataFlair highlights several beginner variable operations:
#
# - Assigning a value
# - Multiple assignment
# - Assigning the same value to multiple variables
# - Swapping variables
# - Deleting variables with `del`
# - Checking a value's data type with `type()`

# %%
# Basic variable assignment
student_name = "Alice"
student_score = 95
course = "DTSC 3020"

print(student_name)
print(student_score)
print(course)

# %% [markdown]
# ## Multiple Assignment and Swapping Variables

# %%
# Multiple assignment
age, city = 21, "Denton"
print(age, city)

# Assign same value to multiple variables
x = y = z = 0
print(x, y, z)

# Swapping variables
color1, color2 = "red", "blue"
color1, color2 = color2, color1
print(color1, color2)

# %% [markdown]
# ## Dynamic Typing
#
# Python is dynamically typed, meaning a variable can refer to values of different types during program execution.

# %%
value = 10
print(value, type(value))

value = "Python"
print(value, type(value))

value = 3.14
print(value, type(value))

# %% [markdown]
# <div class="warning">
# <b>Important:</b> Dynamic typing is convenient, but it also means you must test code carefully. AI-generated code may fail if a variable contains a different type than expected.
# </div>

# %% [markdown]
# # Part 3. Numeric Data Types and Conversion
#
# **Assigned reading:** [Python Numeric Data Types — DataFlair](https://data-flair.training/blogs/python-number-types-conversion/)
#
# Python's main numeric types include:
#
# | Type | Meaning | Example |
# |---|---|---|
# | `int` | whole number | `42` |
# | `float` | decimal number | `3.14` |
# | `complex` | real and imaginary parts | `2 + 3j` |
#
# DataFlair also discusses type conversion, including `int()`, `float()`, and `complex()`. One important detail is that `int(7.7)` truncates to `7` rather than rounding up.

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Data types" width="950"/><p class="figcap">Core Python data types for Week 2.</p></div>

# %%
print(type(42))
print(type(3.14))
print(type(2 + 3j))

print(int(7.7))       # truncates, does not round
print(float(7))
print(complex(2, 3))

# %% [markdown]
# ## Binary, Octal, and Hexadecimal Preview
#
# DataFlair's numeric data type tutorial also introduces different number representations.

# %%
binary_value = 0b10
octal_value = 0o10
hex_value = 0xF

print(binary_value)   # 2
print(octal_value)    # 8
print(hex_value)      # 15

# %% [markdown]
# # Part 4. Identifiers
#
# **Assigned reading:** [Identifiers in Python — DataFlair](https://data-flair.training/blogs/identifiers-in-python/)
#
# An identifier is a name used for variables, functions, classes, modules, and objects.
#
# Good identifiers make code easier to read, debug, and review.

# %% [markdown]
# ## Identifier Rules
#
# A Python identifier:
#
# - Can contain letters, digits, and underscores
# - Cannot start with a digit
# - Cannot contain spaces
# - Cannot use special symbols such as `$` or `-`
# - Should not be a Python keyword such as `class`, `for`, or `if`

# %%
import keyword

names = ["student_name", "2score", "student name", "total_score", "class", "score$"]

for name in names:
    print(name, "| identifier?", name.isidentifier(), "| keyword?", keyword.iskeyword(name))

# %% [markdown]
# ## Naming Practice
#
# Use meaningful names. In this course, prefer `snake_case` for variables and functions.

# %%
# Less clear
x = 95

# More clear
assignment_score = 95

print(assignment_score)

# %% [markdown]
# # Part 5. Variable Scope
#
# **Assigned reading:** [Python Variable Scope — DataFlair](https://data-flair.training/blogs/python-variable-scope/)
#
# Scope means where a variable can be seen and used.
#
# DataFlair explains four important scope ideas:
#
# | Scope | Meaning |
# |---|---|
# | Local | Variable created inside a function |
# | Global | Variable created outside functions |
# | Built-in | Names Python already provides, such as `print`, `len`, and `sum` |
# | Enclosed | Variable in an outer function used by an inner function |

# %%
course = "DTSC 3020"   # global variable

def show_course():
    print("Inside function:", course)

show_course()
print("Outside function:", course)

# %% [markdown]
# ## Local Scope

# %%
def calculate_bonus():
    bonus = 5   # local variable
    print("Inside function, bonus =", bonus)

calculate_bonus()

# Uncommenting the next line will cause an error because bonus is local.
# print(bonus)

# %% [markdown]
# ## Enclosed Scope Preview

# %%
def outer_function():
    message = "Hello from outer function"

    def inner_function():
        print(message)

    inner_function()

outer_function()

# %% [markdown]
# # Part 6. Strings
#
# **Assigned reading:** [Python String — DataFlair](https://data-flair.training/blogs/python-string/)
#
# A string is a sequence of characters. DataFlair covers string quotes, multiline strings, immutability, indexing, slicing, escape sequences, functions, and operations.

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Strings" width="950"/></div>

# %% [markdown]
# ## Quotes and Multiline Strings

# %%
single_quote = 'Dogs are "love"'
double_quote = "Python is 'fun'"
multi_line = """Hello
Welcome to DTSC 3020"""

print(single_quote)
print(double_quote)
print(multi_line)

# %% [markdown]
# ## Indexing, Slicing, and Immutability
#
# Strings can be accessed by index, but they cannot be changed in place.

# %%
word = "Python"

print(word[0])
print(word[-1])
print(word[0:3])

# Strings are immutable:
# word[0] = "J"   # This would cause an error

new_word = "J" + word[1:]
print(new_word)

# %% [markdown]
# ## Escape Sequences and String Functions

# %%
print("Hello\nWorld")
print("Name:\tAlice")

text = "  Python Programming  "
print(len(text))
print(text.lower())
print(text.upper())
print(text.strip())
print(text.replace("Python", "AI"))

colors = ["red", "green", "blue"]
print("*".join(colors))

# %% [markdown]
# # Part 7. Operators
#
# **Assigned reading:** [Python Operator — DataFlair](https://data-flair.training/blogs/python-operator/)
#
# DataFlair introduces several classes of Python operators:
#
# - Arithmetic
# - Relational / comparison
# - Assignment
# - Logical
# - Membership
# - Identity
# - Bitwise
#
# Operators are important because they turn simple values into useful code for real-life problems.

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Operators" width="950"/></div>

# %% [markdown]
# ## Arithmetic Operators

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor division:", a // b)
print("Modulus:", a % b)
print("Exponent:", a ** b)

# %% [markdown]
# ## Relational and Logical Operators

# %%
score = 85
attendance = 0.90

print(score >= 90)
print(score >= 80)
print(score == 85)

passed = score >= 70 and attendance >= 0.80
honor = score >= 90 or attendance >= 0.95

print("Passed?", passed)
print("Honor?", honor)
print("Not passed?", not passed)

# %% [markdown]
# ## Assignment, Membership, and Identity Operators

# %%
points = 10
points += 5
print(points)

topics = ["Python", "Data Science", "AI"]
print("Python" in topics)
print("Java" not in topics)

a = None
print(a is None)
print(a is not None)

# %% [markdown]
# ## Bitwise Operators Preview
#
# Bitwise operators are less important for beginners but useful in lower-level programming, flags, and some advanced tasks.

# %%
x = 5   # binary: 0101
y = 3   # binary: 0011

print("x & y:", x & y)
print("x | y:", x | y)
print("x ^ y:", x ^ y)

# %% [markdown]
# ## Operator Precedence
#
# DataFlair notes that Python follows rules of precedence. Use parentheses to make your code clearer.

# %%
result1 = 2 + 3 * 4
result2 = (2 + 3) * 4

print(result1)
print(result2)

# %% [markdown]
# # Part 8. Random Numbers
#
# **Assigned reading:** [Python Random Number — DataFlair](https://data-flair.training/blogs/python-random-number/)
#
# DataFlair explains that Python generates **pseudorandom numbers**, which appear random but are produced by deterministic processes. The tutorial discusses `seed()`, `random()`, `randint()`, `randrange()`, `gauss()`, `choice()`, `choices()`, `sample()`, and `shuffle()`.

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Random" width="950"/></div>

# %% [markdown]
# ## Basic Random Values

# %%
import random

print(random.random())        # float between 0 and 1
print(random.randint(1, 10))  # integer from 1 to 10
print(random.randrange(0, 10, 2))  # random even number from 0,2,4,6,8

# %% [markdown]
# ## Reproducibility with seed()
#
# A seed lets us reproduce the same random sequence, which is useful for teaching, testing, and debugging.

# %%
import random

random.seed(7)
print(random.random(), random.random(), random.random())

random.seed(7)
print(random.random(), random.random(), random.random())

# %% [markdown]
# ## Random Choice, Sample, and Shuffle

# %%
import random

students = ["Alice", "Ben", "Carla", "David", "Eva"]

print("One random student:", random.choice(students))
print("Two students without replacement:", random.sample(students, 2))

random.shuffle(students)
print("Shuffled list:", students)

# %% [markdown]
# ## Gaussian Values Preview
#
# DataFlair introduces `gauss(mean, standard deviation)` for real-valued distributions.

# %%
import random

random.seed(7)
print(random.gauss(0, 1))
print(random.gauss(0, 1))
print(random.gauss(0, 1))

# %% [markdown]
# # Part 9. GenAI-Era Examples
#
# ## Example 1: Verify AI-Generated Calculations
#
# Suppose a GenAI tool says:
#
# > If a student earns 45 out of 50 points, the percentage is 80%.
#
# Let's verify with Python.

# %%
earned_points = 45
total_points = 50

percentage = earned_points / total_points * 100

print("Correct percentage:", percentage)

# %% [markdown]
# ## Example 2: Validate AI-Generated Text
#
# Suppose an AI-generated project description must mention Python, data, and automation.

# %%
description = '''
This project uses Python to clean data and automate weekly report generation.
'''

required_words = ["Python", "data", "automation"]

for word in required_words:
    print(word, "included?", word.lower() in description.lower())

# %% [markdown]
# ## Example 3: Generate Random Practice Problems
#
# Python can automatically generate practice problems for students.

# %%
import random

a = random.randint(1, 20)
b = random.randint(1, 20)
operator = random.choice(["+", "-", "*"])

if operator == "+":
    answer = a + b
elif operator == "-":
    answer = a - b
else:
    answer = a * b

print(f"Practice problem: What is {a} {operator} {b}?")
print("Answer:", answer)

# %% [markdown]
# # Part 10. In-Class Activities
#
# ## Activity 1: Course Profile
#
# Create variables for your name, major, course, and career goal. Print them using an f-string.

# %%
name = "Your Name"
major = "Your Major"
course = "DTSC 3020"
career_goal = "Your Career Goal"

print(f"My name is {name}. I am majoring in {major}.")
print(f"I am taking {course}, and my career goal is {career_goal}.")

# %% [markdown]
# ## Activity 2: Grade Calculator

# %%
earned_points = 0      # change this
total_points = 100     # change this

percentage = earned_points / total_points * 100

print("Percentage:", percentage)

# %% [markdown]
# ## Activity 3: Text Cleaner

# %%
raw_text = "   GENERATIVE ai and PYTHON   "

clean_text = raw_text.strip().lower()

print("Before:", raw_text)
print("After:", clean_text)

# %% [markdown]
# ## Activity 4: Simple Random Study Tip Generator

# %%
import random

study_tips = [
    "Run every code cell.",
    "Change the examples and observe the output.",
    "Read error messages carefully.",
    "Practice for at least 20 minutes.",
    "Ask questions when you are stuck."
]

tip = random.choice(study_tips)
print("Today's study tip:", tip)

# %% [markdown]
# # Part 11. Click-to-Reveal Quiz
#
# Try each question first, then click to reveal the answer.

# %% [markdown]
# <div class="quiz">
# <p><b>Question 1. What does `type()` do?</b></p>
#
# - A. Prints a random number
# - B. Returns the data type of a value
# - C. Deletes a variable
# - D. Converts text to uppercase
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> B. Returns the data type of a value
#
# <br><br><b>Explanation:</b> The type() function tells us the data type or class of a value.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 2. What is the result of `int(7.7)`?</b></p>
#
# - A. 8
# - B. 7.7
# - C. 7
# - D. Error
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> C. 7
#
# <br><br><b>Explanation:</b> The int() conversion truncates the decimal part; it does not round up.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 3. Which identifier is valid and recommended?</b></p>
#
# - A. 2score
# - B. student name
# - C. student_name
# - D. total-score
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> C. student_name
#
# <br><br><b>Explanation:</b> It uses letters and an underscore, does not start with a digit, and follows Python naming style.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 4. What does string immutability mean?</b></p>
#
# - A. Strings cannot be printed
# - B. Strings cannot be accessed
# - C. A string's characters cannot be changed in place
# - D. Strings cannot contain spaces
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> C. A string's characters cannot be changed in place
#
# <br><br><b>Explanation:</b> You can create a new string, but you cannot directly assign to one character of an existing string.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 5. Why use `random.seed()`?</b></p>
#
# - A. To delete a random number
# - B. To make random sequences reproducible
# - C. To convert a string to a number
# - D. To define a local variable
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> B. To make random sequences reproducible
#
# <br><br><b>Explanation:</b> A seed initializes the pseudorandom generator so the same sequence can be produced again.
# </details>
# </div>

# %% [markdown]
# # Part 12. Exit Ticket
#
# Before the next class, answer these questions:
#
# 1. What is a variable?
# 2. What is the difference between `int`, `float`, and `str`?
# 3. What makes an identifier valid or invalid?
# 4. What is the difference between local and global scope?
# 5. Why are strings immutable?
# 6. What are two operators you used today?
# 7. Why is `random.seed()` useful?

# %% [markdown]
# # Week 2 Summary
#
# Today we covered:
#
# - Random numbers
# - Variables and data types
# - Variable scope
# - Identifiers and naming rules
# - Numeric data types and conversion
# - Strings, slicing, immutability, and methods
# - Operators and precedence
# - GenAI-era examples
# - Beginner programming activities
#
# ## Next Week
#
# **Python Data Structures:** lists, tuples, sets, dictionaries, slicing, and list comprehension.

# %% [markdown]
# # Complete Source List and Credits
#
# ## Assigned Week 2 Sources
#
# 1. [Python Random Number — DataFlair](https://data-flair.training/blogs/python-random-number/)
# 2. [Python Variables and Data Types — DataFlair](https://data-flair.training/blogs/python-variables-and-data-types/)
# 3. [Python Variable Scope — DataFlair](https://data-flair.training/blogs/python-variable-scope/)
# 4. [Identifiers in Python — DataFlair](https://data-flair.training/blogs/identifiers-in-python/)
# 5. [Python Numeric Data Types — DataFlair](https://data-flair.training/blogs/python-number-types-conversion/)
# 6. [Python String — DataFlair](https://data-flair.training/blogs/python-string/)
# 7. [Python Operator — DataFlair](https://data-flair.training/blogs/python-operator/)
#
# ## Additional Reference
#
# - [Python Official Documentation](https://docs.python.org/3/)
#
# ## Diagram Credits
#
# The diagrams in this notebook are instructor-created, high-resolution embedded PNG figures based on the assigned DataFlair Week 2 readings listed above. They are recreated for classroom use so they display reliably in Jupyter, Google Colab, and VS Code notebooks.
